# %% [markdown]
# ---
# title: "Light Measurement Analysis"
# execute:
#   echo: false
#   output: false
# ---

# %%
#Import packages
import pandas as pd
import glob
import numpy as np
import pytz as pt
from pytz import timezone
import datetime
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import pdist, squareform
import ephem
import seaborn as sns
from scipy.integrate import simps

# %%
#Load Data

#This code block needs to be updated to pull data from OSN once the data has been uploaded on to OSN.

def loadData(path):
    df=pd.read_csv(path,parse_dates=['dateTime'])
    df=df.set_index(['dateTime'])
    #df = df.resample('10S').mean()
    df.dropna(how='any', inplace=True)
    df.index = df.index.tz_localize(timezone('UTC')).tz_convert(timezone('US/Central'))
    df = df.div(df.max())
    return df

# %%
#| echo: true
#| output: true
# read bme data from url for may 2nd
#light_url = "https://ncsa.osn.xsede.org/ees230012-bucket01/central-node-8/2023/2023/05/02/MINTS_2cf7f12032305202_AS7526X_2023_05_02.csv"
#df_light = loadData(light_url)
df_light = loadData('testfile.csv') 
df_light.head()
# Out:
#                                   channelA410nm  channelB435nm  channelC460nm  \
# dateTime
# 2023-01-02 03:03:31.789923-06:00       0.014842       0.004237       0.007014
# 2023-01-02 03:04:44.797683-06:00       0.014842       0.004237       0.007014
# 2023-01-02 03:07:10.802676-06:00       0.014842       0.004237       0.007014
# 2023-01-02 03:08:23.797607-06:00       0.014842       0.004237       0.007014
# 2023-01-02 03:09:36.850158-06:00       0.014842       0.004237       0.007014
#
#                                   channelD485nm  channelE510nm  channelF535nm  \
# dateTime
# 2023-01-02 03:03:31.789923-06:00       0.003713       0.003168       0.005187
# 2023-01-02 03:04:44.797683-06:00       0.003713       0.003168       0.005187
# 2023-01-02 03:07:10.802676-06:00       0.003713       0.003168       0.005187
# 2023-01-02 03:08:23.797607-06:00       0.003713       0.003168       0.005187
# 2023-01-02 03:09:36.850158-06:00       0.003713       0.003168       0.005187
#
#                                   channelG560nm  channelH585nm  channelR610nm  \
# dateTime
# 2023-01-02 03:03:31.789923-06:00   3.020314e-08   3.281136e-08       0.004614
# 2023-01-02 03:04:44.797683-06:00   3.020314e-08   3.281136e-08       0.004614
# 2023-01-02 03:07:10.802676-06:00   3.020314e-08   3.290901e-08       0.004614
# 2023-01-02 03:08:23.797607-06:00   3.030415e-08   3.290901e-08       0.004614
# 2023-01-02 03:09:36.850158-06:00   3.020314e-08   3.281136e-08       0.004614
#
#                                   channelI645nm  channelS680nm  channelJ705nm  \
# dateTime
# 2023-01-02 03:03:31.789923-06:00       0.083056       0.002116       0.035227
# 2023-01-02 03:04:44.797683-06:00       0.084164       0.002116       0.035227
# 2023-01-02 03:07:10.802676-06:00       0.083056       0.002116       0.035227
# 2023-01-02 03:08:23.797607-06:00       0.083056       0.002116       0.035227
# 2023-01-02 03:09:36.850158-06:00       0.083056       0.002116       0.035227
#
#                                   channelT730nm  channelU760nm  channelV810nm  \
# dateTime
# 2023-01-02 03:03:31.789923-06:00       0.001104       0.001116       0.001209
# 2023-01-02 03:04:44.797683-06:00       0.001104       0.001116       0.001209
# 2023-01-02 03:07:10.802676-06:00       0.001104       0.001116       0.001209
# 2023-01-02 03:08:23.797607-06:00       0.001104       0.001116       0.001209
# 2023-01-02 03:09:36.850158-06:00       0.001104       0.001116       0.001209
#
#                                   channelW860nm  channelK900nm  channelL940nm
# dateTime
# 2023-01-02 03:03:31.789923-06:00       0.001623       0.021448       0.028037
# 2023-01-02 03:04:44.797683-06:00       0.001623       0.021448       0.028037
# 2023-01-02 03:07:10.802676-06:00       0.001623       0.021448       0.028037
# 2023-01-02 03:08:23.797607-06:00       0.001623       0.021448       0.028037
# 2023-01-02 03:09:36.850158-06:00       0.001623       0.021448       0.028037

# %%
# Create the color palette for the wavelength ranges

def wavelength_to_rgb(wavelength, gamma=0.8):
    
    wavelength = float(wavelength)
    if wavelength >= 380 and wavelength <= 750:
        A = 1.
    else:
        A=0.5
    if wavelength < 380:
        wavelength = 380.
    if wavelength >750:
        wavelength = 750.
    if wavelength >= 380 and wavelength <= 440:
        attenuation = 0.3 + 0.7 * (wavelength - 380) / (440 - 380)
        R = ((-(wavelength - 440) / (440 - 380)) * attenuation) ** gamma
        G = 0.0
        B = (1.0 * attenuation) ** gamma
    elif wavelength >= 440 and wavelength <= 490:
        R = 0.0
        G = ((wavelength - 440) / (490 - 440)) ** gamma
        B = 1.0
    elif wavelength >= 490 and wavelength <= 510:
        R = 0.0
        G = 1.0
        B = (-(wavelength - 510) / (510 - 490)) ** gamma
    elif wavelength >= 510 and wavelength <= 580:
        R = ((wavelength - 510) / (580 - 510)) ** gamma
        G = 1.0
        B = 0.0
    elif wavelength >= 580 and wavelength <= 645:
        R = 1.0
        G = (-(wavelength - 645) / (645 - 580)) ** gamma
        B = 0.0
    elif wavelength >= 645 and wavelength <= 750:
        attenuation = 0.3 + 0.7 * (750 - wavelength) / (750 - 645)
        R = (1.0 * attenuation) ** gamma
        G = 0.0
        B = 0.0
    else:
        R = 0.0
        G = 0.0
        B = 0.0
    return (R,G,B,A)


wavelengths = [410, 435, 460, 485,
       510, 535, 560, 585,
       610, 645, 680, 705,
       730, 760, 810, 860,
       900, 940]
colors = [wavelength_to_rgb(wavelength) for wavelength in wavelengths]

# %%
# Calculate sunrise and sunset times for the specific day

#Change this to get the lat long coordinates from the GPS sensor data
latitude = 32.9857  
longitude = -96.7502

date=df_light.index.date[0]  
observer = ephem.Observer()
observer.lat = str(latitude)
observer.lon = str(longitude)
observer.date = date
sunrise_time = ephem.localtime(observer.previous_rising(ephem.Sun())).time()
sunset_time = ephem.localtime(observer.next_setting(ephem.Sun())).time()


sunrise_timestamp_str = sunrise_time.strftime('%H:%M:%S')
sunset_timestamp_str = sunset_time.strftime('%H:%M:%S')

sunrise_timestamp = pd.Timestamp.combine(date, sunrise_time)
sunset_timestamp = pd.Timestamp.combine(date, sunset_time)

sunrise_timestamps=pd.to_datetime(sunrise_timestamp).tz_localize(timezone('US/Central'))
sunset_timestamps=pd.to_datetime(sunset_timestamp).tz_localize(timezone('US/Central'))

# %%
#Total Irradiance
total_irradiance = np.zeros(len(df_light.index))

for i, row in enumerate(df_light.iterrows()):
    irradiance = row[1].values  
    total_irradiance[i] = simps(irradiance, wavelengths)  

df_light['Total Irradiance'] = total_irradiance

# %%
# | echo: false
#| output: true

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df_light.index, df_light['Total Irradiance'], color='red', label='Total Irradiance')

rolling_mean = df_light['Total Irradiance'].rolling(window='120s').mean()

rolling_std = df_light['Total Irradiance'].rolling(window='120s').std()
upper_bound = rolling_mean + rolling_std
lower_bound = rolling_mean - rolling_std

plt.fill_between(df_light.index, lower_bound, upper_bound, color='green', alpha=0.5, label='Variability')

plt.xlabel('Time')
plt.ylabel('Total Irradiance')
plt.title('Time Series of Total Irradiance with Variability')

plt.axvline(x=sunrise_timestamps, color='blue', linestyle='--', label='Sunrise')
plt.axvline(x=sunset_timestamps, color='red', linestyle='--', label='Sunset')

plt.legend()
plt.grid(False)
plt.show()

# %%
# | echo: false
#| output: true

# Plot stacked area plots
sns.set()  

# Plot stacked area plots
plt.figure(figsize=(12, 6))  

for i, column in enumerate(df_light.columns):
    plt.fill_between(df_light.index, 0, df_light[column], color=colors[i], label=column)

plt.xlabel('Date and Hour')
plt.ylabel('Normalized Spectral Response')
plt.title('Stacked Area Plots for Wavelength Ranges')

plt.axvline(x=sunrise_timestamps, color='blue', linestyle='--', label='Sunrise')
plt.axvline(x=sunset_timestamps, color='red', linestyle='--', label='Sunset')



plt.legend()

plt.show()

# %%
# | echo: false
#| output: true

#Spectral Heat Map

timestamps = df_light.index

plt.figure(figsize=(10, 6))
heatmap = plt.imshow(df_light.T, cmap='hot', aspect='auto')
plt.colorbar(heatmap, label='Normalized Spectral Response')
plt.xlabel('Time')
plt.ylabel('Wavelengths (nm)')
plt.title('Relative Spectral Response Heatmap')

# Adjust the tick labels
x_ticks = range(0, len(timestamps), 20)  # Display every 20th timestamp
x_labels = [timestamps[i].strftime('%H:%M:%S') for i in x_ticks]
plt.xticks(x_ticks, x_labels, rotation=45)
#y_labels = ['410', '435', '460', '485', '510', '535', '560', '585', '610', '645', '680', '705', '730', '760', '810', '860', '900', '940']  
y_labels=list(map(str, wavelengths))
plt.yticks(range(len(df_light.columns)), y_labels)
for i, label in enumerate(plt.gca().get_yticklabels()):
    label.set_color(colors[i % len(colors)])  



sunrise_value = np.argmin(np.abs(pd.to_datetime(timestamps).tz_localize(None) - sunrise_timestamp))
sunset_value = np.argmin(np.abs(pd.to_datetime(timestamps).tz_localize(None) - sunset_timestamp))


plt.axvline(x=sunrise_value, color='blue', linestyle='--', label='Sunrise')
plt.axvline(x=sunset_value, color='red', linestyle='--', label='Sunset')

plt.legend()

plt.grid(False)

plt.tight_layout()
plt.show()

# %%
# | echo: false
#| output: true
import pandas as pd
import matplotlib.pyplot as plt


# Define the moving time window size in seconds
window_size = '120S'

rolling_std = df_light.rolling(window=window_size).std()

num_wavelengths = len(df_light.columns)

num_rows = num_wavelengths
num_cols = 1

fig_width = 12
fig_height = 4 * num_wavelengths 

fig, axs = plt.subplots(num_rows, num_cols, figsize=(fig_width, fig_height), sharex=True)

for i, column in enumerate(df_light.columns):
    ax = axs[i] if num_wavelengths > 1 else axs  
    ax.plot(df_light.index, df_light[column], label=column)
    ax.fill_between(df_light.index, df_light[column] - rolling_std[column], df_light[column] + rolling_std[column],
                    color='green', alpha=0.3)
    ax.set_ylabel('Spectral Response')
    ax.set_title(column)

axs[-1].set_xlabel('Time')

fig.tight_layout()

plt.show()

# %%
#| echo: false
#| output: true
print(f"The sunrise was at {sunrise_timestamp_str} AM")
print(f"The sunset was at {sunset_timestamp_str} PM")
# Out:
# The sunrise was at 07:29:37 AM
# The sunset was at 17:32:20 PM
